# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ppe-data/labels/-4216-_png-jpg1_jpg.rf.cf75ee6c979816385c13853a3a7f3478.txt
# /kaggle/input/ppe-data/labels/001921-jpg0_jpg.rf.e6ec1ebf355b67351c6fca470052fc45.txt
# /kaggle/input/ppe-data/labels/helmet999958-jpg0_jpg.rf.c629ee81011a92729462159602b8f6e3.txt
# /kaggle/input/ppe-data/labels/001647-jpg1_jpg.rf.fb06c189ff63e80be1b71e552abec4b0.txt
# /kaggle/input/ppe-data/labels/005228-jpg3_jpg.rf.204c5cec168cb3574ffd9df798b3cc19.txt
# /kaggle/input/ppe-data/labels/001157-jpg2_jpg.rf.b9c07fb2f8ebd03e29fedff9daf2a398.txt
# /kaggle/input/ppe-data/labels/005237-jpg7_jpg.rf.9f361c445f4b9c1425fe211465f9b76e.txt
# /kaggle/input/ppe-data/labels/001360-jpg4_jpg.rf.7a0ba71cf7113f71b1f2061766cf0ddc.txt
# /kaggle/input/ppe-data/labels/001147-jpg1_jpg.rf.9f97df3a729e6c7791862299bf55d9c8.txt
# /kaggle/input/ppe-data/labels/001363-jpg3_jpg.rf.3a26e1619fec4e377363748c6c1fcb3e.txt
# /kaggle/input/ppe-data/labels/001751-jpg1_jpg.rf.a71764cb12e5340d9aeac3e4a331be05.txt
# ...

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.5/756.5 kB 27.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
ppe_model=YOLO("yolov8m.pt")
ppe_model.train(data="/kaggle/input/config4/ppe-config.yaml",epochs=30)
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r file.zip /kaggle/working/runs/detect/train5
# Out:
#   adding: kaggle/working/runs/detect/train5/ (stored 0%)
#   adding: kaggle/working/runs/detect/train5/events.out.tfevents.1715275216.c05b2d6270db.34.4 (deflated 92%)
#   adding: kaggle/working/runs/detect/train5/train_batch1.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/train5/labels.jpg (deflated 28%)
#   adding: kaggle/working/runs/detect/train5/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train5/weights/last.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/train5/weights/best.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/train5/val_batch2_labels.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/train5/results.csv (deflated 83%)
#   adding: kaggle/working/runs/detect/train5/train_batch1122.jpg (deflated 19%)
#   adding: kaggle/working/runs/detect/train5/val_batch1_pred.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/train5/confusion_matrix_normalized.png (deflated 25%)
# ...

# %%
# !ls
# Out:
# file.zip  runs	wandb  yolov8m.pt  yolov8n.pt

# %%
from IPython.display import FileLink
FileLink(r'file.zip')
# Out:
# /kaggle/working/file.zip

# %%
ppe_model_weight=YOLO("/kaggle/working/runs/detect/train5/weights/best.pt")

# %%
import

# %%
from PIL import Image
import cv2
img=cv2.imread("/kaggle/input/ppe-test/ppe_test1.jpeg")
predict=ppe_model_weight.predict(img)[0]
print(predict)
# Out:
# 0: 416x640 3 hats, 1 vest, 160.8ms
# Speed: 3.4ms preprocess, 160.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'boots', 1: 'gloves', 2: 'hat', 3: 'ppe-suit', 4: 'vest'}
# obb: None
# orig_img: array([[[ 95,  90,  87],
#         [ 95,  90,  87],
#         [ 94,  89,  86],
#         ...,
#         [  8,   9,  13],
#         [ 19,  20,  24],
#         [ 15,  16,  20]],
#
#        [[ 94,  89,  86],
#         [ 94,  89,  86],
#         [ 93,  88,  85],
#         ...,
#         [ 22,  23,  27],
#         [ 13,  16,  20],
#         [ 20,  21,  25]],
#
#        [[ 94,  89,  86],
#         [ 94,  89,  86],
#         [ 94,  89,  86],
#         ...,
#         [ 66,  69,  73],
#         [ 55,  60,  63],
#         [ 48,  51,  55]],
#
#        ...,
#
#        [[ 28,  47,  55],
#         [ 29,  48,  56],
# ...

# %%
predict=predict.plot(line_width=1)
predict=predict[:,:,::-1]
predict=Image.fromarray(predict)
predict.save("output_img.jpeg")
